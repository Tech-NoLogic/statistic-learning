# %%
import numpy as np

from model import Perception

# %%
num_train_data = 5

train_x = np.array([np.random.rand(2) for i in range(num_train_data)])
train_y = np.array([np.random.choice([1, -1], 1) for i in range(num_train_data)])

# %%
model = Perception()

# %%
lr = 0.001
model.train(train_x, train_y, lr)
# Out:
# epoch: 0, i: 0, err: [1]
# w:[-0.00116344 -0.00488588], b:[0.003]

# %%
model.infer(train_x, train_y)
